# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename="Data-New/Data Set 2012 discretized.csv"
data=pd.read_csv(filename)

# %%
data.head()
# Out:
#                      Country  Year  Rank  Total Total discretised  \
# 0                    Somalia  2012   2nd  121.8        High Alert
# 1   Central African Republic  2012  24th  111.2        High Alert
# 2                South Sudan  2012   5th  110.0        High Alert
# 3                       Chad  2012  23rd  109.3             Alert
# 4  Congo Democratic Republic  2012   8th  108.4             Alert
#
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                    10.0                       9.8                  9.6
# 1                     9.6                       9.1                  8.5
# 2                     9.7                      10.0                 10.0
# 3                     8.9                       9.8                  9.1
# 4                     9.7                       9.5                  9.3
#
#    E1: Economy  E2: Economic Inequality  \
# 0          9.7                      8.1
# 1          8.0                      8.7
# ...

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# Country                                                                      0
# Year                                                                         0
# Rank                                                                         0
# Total                                                                        0
# Total discretised                                                            0
# C1: Security Apparatus                                                       0
# C2: Factionalized Elites                                                     0
# C3: Group Grievance                                                          0
# E1: Economy                                                                  0
# E2: Economic Inequality                                                      0
# E3: Human Flight and Brain Drain                                             0
# P1: State Legitimacy                                                         0
# ...

# %%
sb.pairplot(data.iloc[0:180,0:10])
#iris = sb.load_dataset("iris")
#sb.pairplot(iris)

# %%
correlation=data.iloc[:,2:].corr()
fig, ax = plt.subplots(figsize=(25,15))
sb.heatmap(data=correlation, cmap='RdYlGn_r', linewidths=0.5, annot=True)
plt.savefig('features_heatmap.png')

# %% [markdown]
# ### Predictive Modeling
